# %%
import numpy as np
import pandas as pd 
import scipy 

import matplotlib.pyplot as plt

x = np.random.normal(1, 1, size=(2, 100))

plt.hist(x[0])
plt.hist(x[1])
plt.title("Rojin ist ein Stinky")
# Out:
# Text(0.5, 1.0, 'Rojin ist ein Stinky')
