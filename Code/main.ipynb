# %%
import numpy as np
import pandas as pd 
import scipy 
import matplotlib.pyplot as plt

from sandpile1d import Sandpile1D

N = 10
system = Sandpile1D(N, 1)

for _ in range(100):
    system.step()
    
plt.bar(range(N), system.get_height_from_slope(system.slopes[-1])[:-1])
# Out:
# <BarContainer object of 10 artists>
